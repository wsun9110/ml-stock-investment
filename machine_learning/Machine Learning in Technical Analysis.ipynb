# %% [markdown]
# # Machine Learning in Technical Analysis
# ---

# %% [markdown]
# What is machine learning?
# >According to MIT, Machine learning is a subfield of artificial intelligence, which is broadly defined as the capability of a machine to imitate intelligent human behavior. (e.g.  recognize a visual scene, understand a text written in natural language, or recognize a voice, etc.)
# >
# From my personal experience
# >Machine learning is about letting machines to find the pattern within existing data and make decisions (including predictions, classifications, etc.) based on them.

# %% [markdown]
# As a result, there are two main parts we need to focus on:
# >1. Prepare data
# >>1.1 Split data into features (x, independent variables) and labels (y, dependent variables)
# <br>1.2 Perform feature scaling, make sure all features are on the same scale
# <br>1.3 Split data into training, validating, and testing sets (train a model using training data, and then test it on testing data to check its performance)
# <br>1.4 Handle missing values
# <br>1.5 Convert non-numerical values to numerical values (machine only understandards numbers)
# 2. Learn data
# >>2.1 [`Choose the correct model`](https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html) (think of a model as a way of thinking)
# <br>2.2 Fit training data to the model
# <br>2.3 Test the model on testing data and evaluate its performance

# %% [markdown]
# ## A linear regression model
# As my mother-in-law also invests in the stock market. Someone she knows says that just by looking at the trading volume and closing price, you can tell the future trend.
# <br>I am not a fan of this strategy although my mother-in-law says it's pretty accurate. So I want to test out how it works.
# <br>Suppose we want to predict stock price in 5 days using today's price and volume data

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data_path = 'stock_data/'
stock_code = '600000_浦发银行.csv'
df = pd.read_csv(data_path + stock_code)
df['Adj Close T+5'] = df['Adj Close'].shift(-5)
df.head(10)
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close  \
# 0   4/01/2000  3.005759  2.885668  2.912484  2.981274   38562183   1.814433
# 1   5/01/2000  3.029077  2.932305  2.981274  2.947462   45052693   1.793855
# 2   6/01/2000  3.066387  2.920646  2.935803  3.030243   53430896   1.844237
# 3   7/01/2000  3.206298  3.045400  3.066387  3.136342  183161852   1.908809
# 4  10/01/2000  3.247105  3.114190  3.148002  3.177150  141859094   1.933645
# 5  11/01/2000  3.182979  3.045400  3.177150  3.054728   80543448   1.859138
# 6  12/01/2000  3.031409  2.891498  3.031409  2.928807  302548283   1.782502
# 7  13/01/2000  2.943964  2.891498  2.914816  2.903157   68406039   1.766890
# 8  14/01/2000  2.914816  2.787730  2.900825  2.821542  153198958   1.717219
# 9  17/01/2000  2.849524  2.769075  2.807551  2.844861   69485695   1.731411
#
#    Adj Close T+5
# 0       1.859138
# 1       1.782502
# 2       1.766890
# 3       1.717219
# 4       1.731411
# 5       1.712962
# 6       1.712252
# 7       1.734249
# 8       1.722186
# 9       1.715800

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

# handle missing data by dropping nan rows
df.dropna(inplace=True)

# split data into features and labels
X = df[['Volume','Adj Close']]
y = df['Adj Close T+5']

# perform feature scaling, so that Volume and Adj Close are on the same scale
X = scale(X)

# split data into training and testing sets
# turn shuffle to False as what we have is a time series data, and we want to keep them in order
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=False)
# Out:
# C:\Machine_Learning\sample_project_1\refix\lib\site-packages\sklearn\preprocessing\_data.py:194: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
# choose a model
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)

# train the model
reg.fit(X_train,y_train)

# test the model
reg.score(X_test,y_test)
# Out:
# 0.8690433529582906

# %% [markdown]
# For a linear regression model, the score is R-squared. It means how much of the variance within the data can be explained by our features. As 87% of the variance can be explained, it is a relatively high R-squared score.
# We can also print the details of how the model predicts each test sample, and compare it with its true value.

# %%
# display results
# use zip() to output a pair of (x,y) each loop
for each_x, each_y in zip(X_test, y_test):
    # reshape each of our sample to (1,2), meaning 1 row, 2 columns
    y_pred = reg.predict(each_x.reshape(1,-1))
    print(f'Predicted y is {y_pred}, true y is {each_y}')
# Out:
# Predicted y is [9.84437372], true y is 9.973309517
# Predicted y is [9.87638989], true y is 9.920680046
# Predicted y is [9.87670689], true y is 9.854890823
# Predicted y is [9.98284204], true y is 9.815420151
# Predicted y is [9.98168484], true y is 9.775947571
# Predicted y is [9.94841658], true y is 9.710161209
# Predicted y is [9.89625524], true y is 9.611480713
# Predicted y is [9.83156438], true y is 9.703583717
# Predicted y is [9.79559019], true y is 10.0062027
# Predicted y is [9.75681473], true y is 10.04567432
# Predicted y is [9.68735322], true y is 10.04567432
# Predicted y is [9.59052834], true y is 10.0062027
# Predicted y is [9.68210657], true y is 9.874629021
# Predicted y is [9.98652967], true y is 9.881207466
# Predicted y is [10.02330367], true y is 9.894365311
# Predicted y is [10.02248201], true y is 10.15093422
# Predicted y is [9.98454444], true y is 10.17724895
# Predicted y is [9.85303095], true y is 11.20297241
# Predicted y is [9.85925351], true y is 11.12499332
# Predicted y is [9.87262146], true y is 11.12499332
# Predicted y is [10.13549067], true y is 11.19430733
# Predicted y is [10.16090289], true y is 11.16831493
# Predicted y is [11.1989044], true y is 11.1336565
# Predicted y is [11.11552534], true y is 11.09033585
# Predicted y is [11.10764749], true y is 11.12499332
# Predicted y is [11.17460863], true y is 11.12499332
# Predicted y is [11.14672761], true y is 11.20297241
# Predicted y is [11.11166655], true y is 11.07300663
# Predicted y is [11.06357499], true y is 10.90838432
# Predicted y is [11.10161127], true y is 10.79574871
# Predicted y is [11.09959976], true y is 10.72643375
# Predicted y is [11.18550217], true y is 10.70044231
# Predicted y is [11.05100947], true y is 10.70044231
# Predicted y is [10.88438904], true y is 10.64845467
# Predicted y is [10.77251031], true y is 10.69177723
# Predicted y is [10.70125127], true y is 10.89105606
# Predicted y is [10.67658429], true y is 10.95170689
# Predicted y is [10.67070496], true y is 10.95170689
# Predicted y is [10.62446154], true y is 11.00369167
# Predicted y is [10.66629497], true y is 11.08167171
# Predicted y is [10.87427258], true y is 11.05567837
# Predicted y is [10.92951385], true y is 10.96037006
# Predicted y is [10.92851185], true y is 10.88239288
# Predicted y is [10.97857961], true y is 10.87372684
# Predicted y is [11.05981718], true y is 10.93437767
# Predicted y is [11.02941026], true y is 10.9690361
# Predicted y is [10.93416871], true y is 10.91704845
# Predicted y is [10.85676752], true y is 10.85639858
# Predicted y is [10.84787175], true y is 11.09033585
# Predicted y is [10.90702318], true y is 11.14232159
# Predicted y is [10.94290653], true y is 11.49755859
# Predicted y is [10.88953702], true y is 11.77481747
# Predicted y is [10.82933805], true y is 11.92211151
# Predicted y is [11.07111563], true y is 11.74015999
# Predicted y is [11.12086839], true y is 11.86145973
# Predicted y is [11.47842681], true y is 11.80080986
# Predicted y is [11.75916461], true y is 11.65351677
# Predicted y is [11.90983748], true y is 11.84413147
# Predicted y is [11.71508414], true y is 11.70550251
# Predicted y is [11.83544499], true y is 11.59286594
# Predicted y is [11.77178984], true y is 11.59286594
# Predicted y is [11.62658747], true y is 11.67084599
# Predicted y is [11.81814795], true y is 11.57553673
# Predicted y is [11.67914288], true y is 11.63618851
# Predicted y is [11.56681948], true y is 11.64485264
# Predicted y is [11.56385402], true y is 11.33293629
# Predicted y is [11.64045787], true y is 11.15098667
# Predicted y is [11.54801606], true y is 11.20297241
# Predicted y is [11.61080691], true y is 11.15098667
# Predicted y is [11.61912045], true y is 11.05567837
# Predicted y is [11.31051231], true y is 11.08167171
# Predicted y is [11.12735355], true y is 10.98636436
# Predicted y is [11.17495985], true y is 10.88239288
# Predicted y is [11.12243518], true y is 10.90838432
# Predicted y is [11.02857951], true y is 10.8217411
# Predicted y is [11.05593163], true y is 10.85639858
# Predicted y is [10.96655932], true y is 10.83907032
# Predicted y is [10.85760974], true y is 10.83907032
# Predicted y is [10.88561527], true y is 10.76975536
# Predicted y is [10.79574261], true y is 10.89105606
# Predicted y is [10.83091242], true y is 10.8044138
# Predicted y is [10.81326439], true y is 11.07300663
# Predicted y is [10.8129954], true y is 11.16831493
# Predicted y is [10.74705482], true y is 11.22896481
# Predicted y is [10.87261028], true y is 11.15098667
# Predicted y is [10.78199198], true y is 11.01235676
# Predicted y is [11.05990705], true y is 11.06434345
# Predicted y is [11.14969707], true y is 11.07300663
# Predicted y is [11.20464326], true y is 11.28961563
# Predicted y is [11.12701806], true y is 11.22896481
# Predicted y is [10.98697566], true y is 11.1336565
# Predicted y is [11.03807534], true y is 11.28961563
# Predicted y is [11.04625847], true y is 11.2549572
# Predicted y is [11.26672717], true y is 11.29827881
# Predicted y is [11.20138514], true y is 11.15098667
# Predicted y is [11.10699154], true y is 11.1336565
# Predicted y is [11.26564508], true y is 11.11632824
# Predicted y is [11.22956312], true y is 11.18564224
# Predicted y is [11.27256557], true y is 11.17697811
# Predicted y is [11.12347849], true y is 11.15964985
# Predicted y is [11.10524529], true y is 11.15098667
# Predicted y is [11.08807257], true y is 11.16831493
# Predicted y is [11.15846884], true y is 11.21163654
# Predicted y is [11.14914566], true y is 11.14232159
# Predicted y is [11.13060509], true y is 11.1336565
# Predicted y is [11.12200929], true y is 11.12499332
# Predicted y is [11.13977377], true y is 11.15098667
# Predicted y is [11.18621774], true y is 11.29827881
# Predicted y is [11.11362888], true y is 11.35026646
# Predicted y is [11.10552018], true y is 11.31560707
# Predicted y is [11.09661113], true y is 11.30694389
# Predicted y is [11.12196981], true y is 11.21163654
# Predicted y is [11.27270671], true y is 11.29827881
# Predicted y is [11.32143221], true y is 11.2549572
# Predicted y is [11.28581561], true y is 11.32427216
# Predicted y is [11.27698959], true y is 11.37625885
# Predicted y is [11.1825139], true y is 11.27228546
# Predicted y is [11.26916331], true y is 11.12499332
# Predicted y is [11.22490167], true y is 11.14232159
# Predicted y is [11.29776893], true y is 11.17697811
# Predicted y is [11.35047636], true y is 11.10766506
# Predicted y is [11.24247788], true y is 11.1336565
# Predicted y is [11.09753477], true y is 11.00369167
# Predicted y is [11.11425873], true y is 10.92571449
# Predicted y is [11.14797525], true y is 10.86506271
# Predicted y is [11.07949263], true y is 10.85639858
# Predicted y is [11.1063023], true y is 10.89972019
# Predicted y is [10.98205947], true y is 10.8044138
# Predicted y is [10.89760506], true y is 10.86506271
# Predicted y is [10.83908087], true y is 10.89972019
# Predicted y is [10.83205174], true y is 10.87372684
# Predicted y is [10.87329149], true y is 10.94304276
# Predicted y is [10.77676013], true y is 11.09033585
# Predicted y is [10.83949169], true y is 10.91704845
# Predicted y is [10.87382366], true y is 10.91704845
# Predicted y is [10.84548832], true y is 10.73509789
# Predicted y is [10.91856706], true y is 11.07300663
# Predicted y is [11.0687781], true y is 11.1336565
# Predicted y is [10.89066539], true y is 11.21163654
# Predicted y is [10.88996033], true y is 11.46290112
# Predicted y is [10.70965694], true y is 11.31560707
# Predicted y is [11.05540557], true y is 11.34160137
# Predicted y is [11.10988093], true y is 11.35026646
# Predicted y is [11.1943495], true y is 11.21163654
# Predicted y is [11.44444423], true y is 11.21163654
# Predicted y is [11.2936636], true y is 11.18564224
# Predicted y is [11.31678858], true y is 11.18564224
# Predicted y is [11.32785851], true y is 11.19430733
# Predicted y is [11.18414968], true y is 11.41091633
# Predicted y is [11.18512001], true y is 11.22896481
# Predicted y is [11.15898646], true y is 11.22896481
# Predicted y is [11.15882021], true y is 11.20297241
# Predicted y is [11.1671913], true y is 11.23762989
# Predicted y is [11.39380516], true y is 11.04701328
# Predicted y is [11.20259467], true y is 11.03834915
# Predicted y is [11.20148315], true y is 10.99502754
# Predicted y is [11.17517935], true y is 10.93437767
# Predicted y is [11.21036767], true y is 10.96037006
# Predicted y is [11.0197078], true y is 11.04701328
# Predicted y is [11.00970826], true y is 11.02968502
# Predicted y is [10.96615625], true y is 11.00369167
# Predicted y is [10.9057492], true y is 10.93437767
# Predicted y is [10.93129792], true y is 10.90838432
# Predicted y is [11.01822149], true y is 10.95170689
# Predicted y is [11.00198333], true y is 10.93437767
# Predicted y is [10.97539664], true y is 10.86506271
# Predicted y is [10.90573267], true y is 10.90838432
# Predicted y is [10.88024077], true y is 11.02102089
# Predicted y is [10.92288924], true y is 10.9690361
# Predicted y is [10.90780063], true y is 10.9690361
# Predicted y is [10.83765324], true y is 10.99502754
# Predicted y is [10.87987388], true y is 10.98636436
# Predicted y is [10.99393416], true y is 11.00369167
# Predicted y is [10.94295928], true y is 11.2809515
# Predicted y is [10.94172319], true y is 11.21163654
# Predicted y is [10.96800445], true y is 11.18564224
# Predicted y is [10.95941983], true y is 11.2809515
# Predicted y is [10.97603771], true y is 11.17697811
# Predicted y is [11.26023053], true y is 11.35026646
# Predicted y is [11.18461958], true y is 11.4715662
# Predicted y is [11.15703546], true y is 11.4715662
# Predicted y is [11.25658514], true y is 11.06434345
# Predicted y is [11.15469862], true y is 11.17697811
# Predicted y is [11.33380383], true y is 11.75748825
# Predicted y is [11.45270729], true y is 11.82680321
# Predicted y is [11.46016223], true y is 11.61885929
# Predicted y is [11.06703671], true y is 11.6621809
# Predicted y is [11.17244608], true y is 11.35892963
# Predicted y is [11.77080643], true y is 11.41091633
# Predicted y is [11.81468987], true y is 11.52355194
# Predicted y is [11.61269352], true y is 11.38492298
# Predicted y is [11.64782217], true y is 11.68817425
# Predicted y is [11.34003358], true y is 11.67950916
# Predicted y is [11.39304855], true y is 11.65351677
# Predicted y is [11.51218607], true y is 11.35026646
# Predicted y is [11.36145567], true y is 11.07300663
# Predicted y is [11.67326394], true y is 10.8217411
# Predicted y is [11.67632981], true y is 10.83907032
# Predicted y is [11.64502564], true y is 10.79574871
# Predicted y is [11.33160538], true y is 10.94304276
# Predicted y is [11.06036232], true y is 11.02102089
# Predicted y is [10.79958087], true y is 11.02968502
# Predicted y is [10.81561403], true y is 10.99502754
# Predicted y is [10.76969063], true y is 10.79574871
# Predicted y is [10.91758453], true y is 10.8044138
# Predicted y is [10.99485465], true y is 10.7524271
# Predicted y is [11.00473559], true y is 10.76109123
# Predicted y is [10.97018159], true y is 10.8217411
# Predicted y is [10.77059593], true y is 10.8217411
# Predicted y is [10.77855731], true y is 10.8044138
# Predicted y is [10.72534769], true y is 10.81307697
# Predicted y is [10.73476298], true y is 10.83040619
# Predicted y is [10.79491519], true y is 10.8217411
# Predicted y is [10.79635487], true y is 10.73509789
# Predicted y is [10.77702675], true y is 10.73509789
# Predicted y is [10.78582955], true y is 10.65711975
# Predicted y is [10.80329092], true y is 10.66578484
# Predicted y is [10.79465722], true y is 10.67444801
# Predicted y is [10.70805817], true y is 10.64845467
# Predicted y is [10.70737318], true y is 10.61379719
# Predicted y is [10.63087509], true y is 10.14592457
# Predicted y is [10.63827929], true y is 10.0592804
# Predicted y is [10.64737786], true y is 10.06794453
# Predicted y is [10.62188305], true y is 10.02462292
# Predicted y is [10.587244], true y is 10.06794453
# Predicted y is [10.12542028], true y is 10.09393692
# Predicted y is [10.03654298], true y is 10.14592457
# Predicted y is [10.0440447], true y is 10.01595974
# Predicted y is [10.00034147], true y is 9.989967346
# Predicted y is [10.04476188], true y is 9.963973999
# Predicted y is [10.06943245], true y is 10.19791031
# Predicted y is [10.12177148], true y is 10.31921005
# Predicted y is [9.99113964], true y is 10.20657349
# Predicted y is [9.96541331], true y is 10.12859631
# Predicted y is [9.93915845], true y is 10.00729561
# Predicted y is [10.17368409], true y is 10.00729561
# Predicted y is [10.29483182], true y is 10.16325283
# Predicted y is [10.18108159], true y is 10.22390366
# Predicted y is [10.10281846], true y is 10.0592804
# Predicted y is [9.98318154], true y is 10.05061722
# Predicted y is [9.98339881], true y is 10.20657349
# Predicted y is [10.13885594], true y is 10.10260296
# Predicted y is [10.19806282], true y is 10.02462292
# Predicted y is [10.0343021], true y is 10.0592804
# Predicted y is [10.02564808], true y is 9.556750298
# Predicted y is [10.18160415], true y is 9.461442947
# Predicted y is [10.07717235], true y is 9.38346386
# Predicted y is [9.99975722], true y is 9.392127037
# Predicted y is [10.03493204], true y is 9.487435341
# Predicted y is [9.54003957], true y is 9.470108032
# Predicted y is [9.4407969], true y is 9.487435341
# Predicted y is [9.3615779], true y is 9.487435341
# Predicted y is [9.37084982], true y is 9.53075695
# Predicted y is [9.46596013], true y is 9.522091866
# Predicted y is [9.44742263], true y is 9.418121338
# Predicted y is [9.46437505], true y is 9.38346386
# Predicted y is [9.46511813], true y is 9.444113731
# Predicted y is [9.50848942], true y is 9.478770256
# Predicted y is [9.49983114], true y is 9.426786423
# Predicted y is [9.39626627], true y is 9.357470512
# Predicted y is [9.36110876], true y is 9.348806381
# Predicted y is [9.42192689], true y is 9.279492378
# Predicted y is [9.45665769], true y is 9.322813988
# Predicted y is [9.40395847], true y is 9.218841553
# Predicted y is [9.33555354], true y is 9.045554161
# Predicted y is [9.32618225], true y is 9.140862465
# Predicted y is [9.25760622], true y is 9.253498077
# Predicted y is [9.30068026], true y is 9.314148903
# Predicted y is [9.19693119], true y is 9.236169815
# Predicted y is [9.02621264], true y is 9.140862465
# Predicted y is [9.12280433], true y is 9.20151329
# Predicted y is [9.23163156], true y is 9.028226852
# Predicted y is [9.29177673], true y is 9.028226852
# Predicted y is [9.21441086], true y is 8.967576981
# Predicted y is [9.11901122], true y is 8.84627533
# Predicted y is [9.18046722], true y is 8.854939461
# Predicted y is [9.0083254], true y is 8.924255371
# Predicted y is [9.00718585], true y is 8.595009804
# Predicted y is [8.94653208], true y is 8.56901741
# Predicted y is [8.82618035], true y is 8.517030716
# Predicted y is [8.83451251], true y is 8.456380844
# Predicted y is [8.90385332], true y is 8.283094406
# Predicted y is [8.57874475], true y is 8.213779449
# Predicted y is [8.5498638], true y is 8.118472099
# Predicted y is [8.49866417], true y is 8.231108665
# Predicted y is [8.43842284], true y is 8.283094406
# Predicted y is [8.26570713], true y is 8.049158096
# Predicted y is [8.1966823], true y is 8.101143837
# Predicted y is [8.10180398], true y is 8.066487312
# Predicted y is [8.21472894], true y is 8.023164749
# Predicted y is [8.26511724], true y is 8.118472099
# Predicted y is [8.03247907], true y is 8.317752838
# Predicted y is [8.08444455], true y is 8.291758537
# Predicted y is [8.04872265], true y is 8.127137184
# Predicted y is [8.0058196], true y is 8.291758537
# Predicted y is [8.101516], true y is 8.309270859
# Predicted y is [8.29997441], true y is 8.23922348
# Predicted y is [8.27286748], true y is 8.265491486
# Predicted y is [8.10922997], true y is 8.326782227
# Predicted y is [8.27377414], true y is 8.3705616
# Predicted y is [8.29063789], true y is 8.641991615
# Predicted y is [8.22078513], true y is 8.720794678
# Predicted y is [8.24686466], true y is 8.773328781
# Predicted y is [8.30856539], true y is 8.773328781
# Predicted y is [8.35210581], true y is 8.720794678
# Predicted y is [8.62433905], true y is 8.747061729
# Predicted y is [8.70261524], true y is 8.869642258
# Predicted y is [8.75555976], true y is 8.904666901
# Predicted y is [8.75301009], true y is 8.677015305
# Predicted y is [8.70059408], true y is 8.57194519
# Predicted y is [8.72637644], true y is 8.606967926
# Predicted y is [8.84947373], true y is 8.677015305
# Predicted y is [8.88412796], true y is 8.85213089
# Predicted y is [8.65767117], true y is 8.799596786
# Predicted y is [8.55347163], true y is 8.878398895
# Predicted y is [8.58742957], true y is 8.817108154
# Predicted y is [8.65726175], true y is 8.738305092
# Predicted y is [8.83223965], true y is 8.80835247
# Predicted y is [8.77887514], true y is 8.668258667
# Predicted y is [8.85789773], true y is 8.80835247
# Predicted y is [8.79628292], true y is 8.738305092
# Predicted y is [8.71837473], true y is 8.887154579
# Predicted y is [8.78789581], true y is 8.860887527
# Predicted y is [8.64820898], true y is 8.834620476
# Predicted y is [8.78894563], true y is 8.817108154
# Predicted y is [8.71802245], true y is 9.018492699
# Predicted y is [8.86777251], true y is 9.04475975
# Predicted y is [8.84071436], true y is 9.018492699
# Predicted y is [8.81358118], true y is 9.036003113
# Predicted y is [8.79657659], true y is 8.904666901
# Predicted y is [8.99926046], true y is 9.04475975
# Predicted y is [9.02430827], true y is 8.965955734
# Predicted y is [8.99706782], true y is 9.079782486
# Predicted y is [9.01398316], true y is 8.860887527
# Predicted y is [8.88417998], true y is 8.878398895
# Predicted y is [9.02605217], true y is 8.922177315
# Predicted y is [8.94469657], true y is 8.913421631
# Predicted y is [9.05833727], true y is 8.773328781
# Predicted y is [8.84107974], true y is 8.790841103
# Predicted y is [8.85701083], true y is 9.009735107
# Predicted y is [8.9004275], true y is 8.983469009
# Predicted y is [8.89205667], true y is 8.887154579
# Predicted y is [8.7534818], true y is 8.983469009
# Predicted y is [8.77053125], true y is 8.965955734
# Predicted y is [8.99018263], true y is 8.94844532
# Predicted y is [8.96240804], true y is 9.1848526
# Predicted y is [8.86573125], true y is 9.062272072
# Predicted y is [8.9624371], true y is 9.114806175
# Predicted y is [8.94522316], true y is 9.176095963
# Predicted y is [8.92750183], true y is 9.298678398
# Predicted y is [9.165636], true y is 8.895910263
# Predicted y is [9.04083567], true y is 8.887154579
# Predicted y is [9.0950661], true y is 8.904666901
# Predicted y is [9.15525079], true y is 8.580701828
# Predicted y is [9.27900453], true y is 8.782084465
# Predicted y is [8.8783546], true y is 8.782084465
# Predicted y is [8.86729867], true y is 8.799596786
# Predicted y is [8.88411824], true y is 9.009735107
# Predicted y is [8.56400388], true y is 8.922177315
# Predicted y is [8.76288111], true y is 9.08853817
# Predicted y is [8.76149204], true y is 9.298678398
# Predicted y is [8.77910439], true y is 9.149828911
# Predicted y is [8.98982301], true y is 9.403747559
# Predicted y is [8.90209234], true y is 9.491305351
# Predicted y is [9.07003638], true y is 9.56135273
# Predicted y is [9.28019313], true y is 9.447526932
# Predicted y is [9.1308119], true y is 9.587619781
# Predicted y is [9.38636645], true y is 9.613886833
# Predicted y is [9.47081721], true y is 9.535084724
# Predicted y is [9.53943335], true y is 9.789004326
# Predicted y is [9.42700919], true y is 9.753980637
# Predicted y is [9.56629011], true y is 9.657666206
# Predicted y is [9.59104653], true y is 9.543840408
# Predicted y is [9.51276844], true y is 9.683934212
# Predicted y is [9.76872215], true y is 9.412503242
# Predicted y is [9.73001247], true y is 9.456282616
# Predicted y is [9.6342452], true y is 9.473793983
# Predicted y is [9.52115983], true y is 9.368724823
# Predicted y is [9.66060655], true y is 9.430015564
# Predicted y is [9.39091693], true y is 9.42125988
# Predicted y is [9.43470667], true y is 9.526329994
# Predicted y is [9.45136726], true y is 9.359968185
# Predicted y is [9.3463675], true y is 9.333701134
# Predicted y is [9.40724535], true y is 9.316189766
# Predicted y is [9.39912127], true y is 9.193608284
# Predicted y is [9.50378424], true y is 9.193608284
# Predicted y is [9.33812715], true y is 9.1848526
# Predicted y is [9.31123444], true y is 9.263654709
# Predicted y is [9.29354002], true y is 9.307434082
# Predicted y is [9.17151989], true y is 9.377480507
# Predicted y is [9.17147798], true y is 9.648911476
# Predicted y is [9.16284394], true y is 9.70144558
# Predicted y is [9.24174573], true y is 9.631399155
# Predicted y is [9.28564726], true y is 9.543840408
# Predicted y is [9.35640233], true y is 9.535084724
# Predicted y is [9.62858205], true y is 9.482550621
# Predicted y is [9.67815203], true y is 9.386237144
# Predicted y is [9.60895732], true y is 9.394990921
# Predicted y is [9.5215018], true y is 9.456282616
# Predicted y is [9.51116364], true y is 9.298678398
# Predicted y is [9.45949642], true y is 9.438770294
# Predicted y is [9.3637173], true y is 9.254899025
# Predicted y is [9.37184308], true y is 9.22863102
# Predicted y is [9.43380977], true y is 8.974713326
# Predicted y is [9.27735727], true y is 8.817108154
# Predicted y is [9.41635939], true y is 8.677015305
# Predicted y is [9.23316196], true y is 8.57194519
# Predicted y is [9.20626932], true y is 8.466875076
# Predicted y is [8.95537721], true y is 8.458119392
# Predicted y is [8.79724063], true y is 8.580701828
# Predicted y is [8.65792422], true y is 8.493143082
# Predicted y is [8.55475382], true y is 8.589457512
# Predicted y is [8.44832141], true y is 8.720794678
# Predicted y is [8.44044119], true y is 8.738305092
# Predicted y is [8.56255702], true y is 8.720794678
# Predicted y is [8.47488446], true y is 8.747061729
# Predicted y is [8.57019246], true y is 8.720794678
# Predicted y is [8.7020799], true y is 8.799596786
# Predicted y is [8.71907871], true y is 8.80835247
# Predicted y is [8.70058149], true y is 8.85213089
# Predicted y is [8.72774767], true y is 8.869642258
# Predicted y is [8.70068313], true y is 8.904666901
# Predicted y is [8.77957134], true y is 9.132317543
# Predicted y is [8.78845259], true y is 9.062272072
# Predicted y is [8.83147572], true y is 8.974713326
# Predicted y is [8.84859117], true y is 8.992224693
# Predicted y is [8.88469453], true y is 9.08853817
# Predicted y is [9.11225047], true y is 9.193608284
# Predicted y is [9.04121668], true y is 9.123561859
# Predicted y is [8.95366133], true y is 9.263654709
# Predicted y is [8.97113854], true y is 9.193608284
# Predicted y is [9.06689195], true y is 9.394990921
# Predicted y is [9.17213843], true y is 9.430015564
# Predicted y is [9.10261997], true y is 9.368724823
# Predicted y is [9.24241975], true y is 9.386237144
# Predicted y is [9.17168618], true y is 9.508817673
# Predicted y is [9.37341776], true y is 9.473793983
# Predicted y is [9.40756064], true y is 9.333701134
# Predicted y is [9.34664294], true y is 9.491305351
# Predicted y is [9.36365961], true y is 9.456282616
# Predicted y is [9.48744016], true y is 9.482550621
# Predicted y is [9.45125633], true y is 9.447526932
# Predicted y is [9.31144941], true y is 9.640154839
# Predicted y is [9.46873567], true y is 10.43693447
# Predicted y is [9.43457468], true y is 10.20052624
# Predicted y is [9.46028595], true y is 10.35813141
# Predicted y is [9.42578449], true y is 10.27933025
# Predicted y is [9.61773086], true y is 10.52449226
# Predicted y is [10.41985098], true y is 10.52449226
# Predicted y is [10.18310593], true y is 10.48946857
# Predicted y is [10.33855736], true y is 10.52449226
# Predicted y is [10.2561112], true y is 10.40191078
# Predicted y is [10.50328871], true y is 10.06919003
# Predicted y is [10.5059918], true y is 10.04292202
# Predicted y is [10.4673213], true y is 10.01665497
# Predicted y is [10.50210152], true y is 10.01665497
# Predicted y is [10.37986025], true y is 10.03416729
# Predicted y is [10.04843144], true y is 10.00790024
# Predicted y is [10.020682], true y is 10.14799309
# Predicted y is [9.9960424], true y is 10.1129694
# Predicted y is [9.9946966], true y is 10.1129694
# Predicted y is [10.01122497], true y is 10.03416729
# Predicted y is [9.98503159], true y is 9.972876549
# Predicted y is [10.1258385], true y is 9.657666206
# Predicted y is [10.0889164], true y is 9.710202217
# Predicted y is [10.08889469], true y is 9.70144558
# Predicted y is [10.01135456], true y is 9.657666206
# Predicted y is [9.95035021], true y is 9.876561165
# Predicted y is [9.63912414], true y is 10.01665497
# Predicted y is [9.68811455], true y is 10.01665497
# Predicted y is [9.68079838], true y is 10.06919003
# Predicted y is [9.63559532], true y is 10.25306225
# Predicted y is [9.85752223], true y is 10.26181793
# Predicted y is [9.99833021], true y is 10.10421276
# Predicted y is [9.99535985], true y is 10.05167866
# Predicted y is [10.04813351], true y is 10.04292202
# Predicted y is [10.23439465], true y is 10.06043339
# Predicted y is [10.24344402], true y is 10.04292202
# Predicted y is [10.08384351], true y is 10.46320152
# Predicted y is [10.02954208], true y is 10.42817783
# Predicted y is [10.02195479], true y is 10.42817783
# Predicted y is [10.03643108], true y is 10.51573753
# Predicted y is [10.02447985], true y is 10.25306225
# Predicted y is [10.44687988], true y is 10.24430561
# Predicted y is [10.40795514], true y is 10.17425919
# Predicted y is [10.40483758], true y is 10.10421276
# Predicted y is [10.49366866], true y is 9.911585808
# Predicted y is [10.2316825], true y is 10.33186531
# Predicted y is [10.22053331], true y is 10.33186531
# Predicted y is [10.15129806], true y is 10.07794571
# Predicted y is [10.08185441], true y is 9.736469269
# Predicted y is [9.89016955], true y is 9.911585808
# Predicted y is [10.31901616], true y is 9.90282917
# Predicted y is [10.31416684], true y is 9.815270424
# Predicted y is [10.05787712], true y is 9.911585808
# Predicted y is [9.71841881], true y is 9.89407444
# Predicted y is [9.89092461], true y is 9.841538429
# Predicted y is [9.88117549], true y is 9.929097176
# Predicted y is [9.7941542], true y is 9.911585808
# Predicted y is [9.88916814], true y is 9.771492004
# Predicted y is [9.87169181], true y is 9.718956947
# Predicted y is [9.81988749], true y is 9.727712631
# Predicted y is [9.90667393], true y is 9.824028015
# Predicted y is [9.88899076], true y is 9.885317802
# Predicted y is [9.75031043], true y is 9.736469269
# Predicted y is [9.69752047], true y is 9.727712631
# Predicted y is [9.70473342], true y is 9.745224953
# Predicted y is [9.8020335], true y is 9.876561165
# Predicted y is [9.8677042], true y is 9.937852859
# Predicted y is [9.71552986], true y is 9.990386963
# Predicted y is [9.70504256], true y is 10.04292202
# Predicted y is [9.72376943], true y is 10.1655035
# Predicted y is [9.85379304], true y is 10.30995083
# Predicted y is [9.91417562], true y is 10.47245598
# Predicted y is [9.96729473], true y is 10.5627346
# Predicted y is [10.01900643], true y is 10.6439867
# Predicted y is [10.14319487], true y is 10.62593079
# Predicted y is [10.28821182], true y is 10.6710701
# Predicted y is [10.4498866], true y is 10.72523785
# Predicted y is [10.53936083], true y is 11.01413441
# Predicted y is [10.62035104], true y is 10.91482639
# Predicted y is [10.60085442], true y is 10.86065769
# Predicted y is [10.64504268], true y is 10.52662277
# Predicted y is [10.70098314], true y is 10.52662277
# Predicted y is [10.99208116], true y is 10.50856781
# Predicted y is [10.89113713], true y is 10.54467964
# Predicted y is [10.83454718], true y is 10.57176304
# Predicted y is [10.5075348], true y is 10.48148251
# Predicted y is [10.50214777], true y is 10.43634319
# Predicted y is [10.48553143], true y is 10.49051094
# Predicted y is [10.51921257], true y is 10.44537067
# Predicted y is [10.549338], true y is 10.25578308
# Predicted y is [10.45894412], true y is 10.26481152
# Predicted y is [10.41216657], true y is 10.2467556
# Predicted y is [10.46535548], true y is 10.29189491
# Predicted y is [10.41981647], true y is 10.40023136
# Predicted y is [10.23207358], true y is 10.38217545
# Predicted y is [10.23947469], true y is 10.42731571
# Predicted y is [10.22167782], true y is 10.36411953
# Predicted y is [10.26662733], true y is 10.37314701
# Predicted y is [10.37597696], true y is 10.45439911
# Predicted y is [10.35867231], true y is 10.36411953
# Predicted y is [10.40131633], true y is 10.37314701
# Predicted y is [10.33785206], true y is 10.46342754
# Predicted y is [10.34694147], true y is 10.72523785
# Predicted y is [10.42804845], true y is 10.71621037
# Predicted y is [10.33886245], true y is 10.70718193
# Predicted y is [10.34690023], true y is 10.70718193
# Predicted y is [10.43759983], true y is 10.71621037
# Predicted y is [10.70234554], true y is 10.51759434
# Predicted y is [10.69018286], true y is 10.36411953
# Predicted y is [10.68008374], true y is 10.14744759
# Predicted y is [10.68160674], true y is 10.01202869
# Predicted y is [10.69021784], true y is 9.993972778
# Predicted y is [10.49259529], true y is 10.1655035
# Predicted y is [10.34052107], true y is 10.26481152
# Predicted y is [10.12515102], true y is 10.31898022
# Predicted y is [9.99056385], true y is 10.22869968
# Predicted y is [9.97087146], true y is 10.18355942
# Predicted y is [10.14196245], true y is 10.19258785
# Predicted y is [10.2418031], true y is 10.12939262
# Predicted y is [10.29506112], true y is 10.27383995
# Predicted y is [10.20312424], true y is 10.26481152
# Predicted y is [10.15828683], true y is 10.30092335
# Predicted y is [10.16718437], true y is 10.31898022
# Predicted y is [10.10494382], true y is 10.46342754
# Predicted y is [10.25050056], true y is 10.20161629
# Predicted y is [10.23970721], true y is 10.20161629
# Predicted y is [10.27454943], true y is 10.2196722
# Predicted y is [10.29268681], true y is 10.1384201
# Predicted y is [10.43878474], true y is 10.18355942
# Predicted y is [10.17900192], true y is 10.23772812
# Predicted y is [10.18203183], true y is 10.2467556
# Predicted y is [10.19496176], true y is 10.37314701
# Predicted y is [10.11433698], true y is 10.49051094
# Predicted y is [10.15897589], true y is 10.55370712
# Predicted y is [10.21322409], true y is 10.60787487
# Predicted y is [10.22079336], true y is 10.6981554
# Predicted y is [10.34848247], true y is 10.78843403
# Predicted y is [10.46739908], true y is 10.8335743
# Predicted y is [10.52880699], true y is 10.77037811
# Predicted y is [10.58346913], true y is 10.66204262
# Predicted y is [10.67302609], true y is 10.77037811
# Predicted y is [10.76320704], true y is 10.77940655
# Predicted y is [10.80656388], true y is 10.78843403
# Predicted y is [10.74353541], true y is 10.60787487
# Predicted y is [10.63662047], true y is 10.60787487
# Predicted y is [10.74426775], true y is 10.66204262
# Predicted y is [10.75231205], true y is 10.8064909
# Predicted y is [10.76333687], true y is 10.74329472
# Predicted y is [10.58193587], true y is 10.68912697
# Predicted y is [10.58121077], true y is 10.74329472
# Predicted y is [10.63619551], true y is 10.82454681
# Predicted y is [10.78537388], true y is 10.79746246
# Predicted y is [10.71796205], true y is 11.23983383
# Predicted y is [10.66389676], true y is 11.68220425
# Predicted y is [10.71741672], true y is 11.81762409
# Predicted y is [10.79957091], true y is 11.80859566
# Predicted y is [10.77073515], true y is 11.88984871
# Predicted y is [11.21943944], true y is 11.53775597
# Predicted y is [11.66406643], true y is 11.6551199
# Predicted y is [11.79268337], true y is 11.67317677
# Predicted y is [11.78289611], true y is 11.60998058
# Predicted y is [11.8614596], true y is 11.81762409
# Predicted y is [11.51285336], true y is 11.64609146
# Predicted y is [11.62653598], true y is 11.4655323
# Predicted y is [11.64357943], true y is 11.52872944
# Predicted y is [11.58080436], true y is 11.36622524
# Predicted y is [11.79637903], true y is 11.29400158
# Predicted y is [11.62485325], true y is 11.51067257
# Predicted y is [11.44182602], true y is 11.50164413
# Predicted y is [11.50232346], true y is 11.69123173
# Predicted y is [11.3405875], true y is 11.66414833
# Predicted y is [11.26611152], true y is 11.519701
# Predicted y is [11.48559062], true y is 11.34816933
# Predicted y is [11.47498693], true y is 11.09538555
# Predicted y is [11.66688858], true y is 11.05024529
# Predicted y is [11.63640211], true y is 11.04121685
# Predicted y is [11.49254309], true y is 10.95996571
# Predicted y is [11.32199383], true y is 10.96899414
# Predicted y is [11.06891433], true y is 11.05024529
# Predicted y is [11.02402858], true y is 11.04121685
# Predicted y is [11.01417029], true y is 10.86968708
# Predicted y is [10.93281944], true y is 10.79746246
# Predicted y is [10.94161192], true y is 10.82454681
# Predicted y is [11.02273194], true y is 10.89676952
# Predicted y is [11.01380969], true y is 10.887743
# Predicted y is [10.84402552], true y is 10.82454681
# Predicted y is [10.77164849], true y is 10.79746246
# Predicted y is [10.79799669], true y is 10.7523222
# Predicted y is [10.86939678], true y is 10.71621037
# Predicted y is [10.86468634], true y is 10.70718193
# Predicted y is [10.79789399], true y is 10.60787487
# Predicted y is [10.76956005], true y is 10.73426723
# Predicted y is [10.72543475], true y is 10.76135063
# Predicted y is [10.68916397], true y is 10.74329472
# Predicted y is [10.67984694], true y is 10.70718193
# Predicted y is [10.58156634], true y is 10.81551743
# Predicted y is [10.70750035], true y is 10.74329472
# Predicted y is [10.73394251], true y is 10.94190979
# Predicted y is [10.71554597], true y is 10.95093822
# Predicted y is [10.67932132], true y is 11.18566513
# Predicted y is [10.7894837], true y is 11.19469357
# Predicted y is [10.71674689], true y is 11.203722
# Predicted y is [10.91862985], true y is 11.21274948
# Predicted y is [10.92494778], true y is 11.01413441
# Predicted y is [11.16118453], true y is 11.08635712
# Predicted y is [11.1673384], true y is 11.05024529
# Predicted y is [11.17499403], true y is 11.09538555
# Predicted y is [11.18601799], true y is 11.12246895
# Predicted y is [10.98778337], true y is 11.14052582
# Predicted y is [11.05781951], true y is 11.16760921
# Predicted y is [11.02085478], true y is 11.25788975
# Predicted y is [11.06607652], true y is 11.37525272
# Predicted y is [11.09456923], true y is 11.24886131
# Predicted y is [11.1141853], true y is 11.28497314
# Predicted y is [11.14003441], true y is 11.12246895
# Predicted y is [11.23240913], true y is 11.16760921
# Predicted y is [11.34762874], true y is 11.18566513
# Predicted y is [11.22209597], true y is 11.203722
# Predicted y is [11.25650632], true y is 11.22177792
# Predicted y is [11.09547667], true y is 11.05927372
# Predicted y is [11.13931398], true y is 11.01413441
# Predicted y is [11.15632791], true y is 11.04121685
# Predicted y is [11.1746123], true y is 11.05927372
# Predicted y is [11.19375058], true y is 10.90579796
# Predicted y is [11.03211049], true y is 10.62593079
# Predicted y is [10.98597317], true y is 10.2467556
# Predicted y is [11.01234732], true y is 9.45229435
# Predicted y is [11.03109698], true y is 9.623825073
# Predicted y is [10.87921408], true y is 9.659936905
# Predicted y is [10.60618276], true y is 9.741189003
# Predicted y is [10.22827406], true y is 9.804385185
# Predicted y is [9.43922067], true y is 9.723133087
# Predicted y is [9.60653958], true y is 9.804385185
# Predicted y is [9.63981291], true y is 9.804385185
# Predicted y is [9.71987909], true y is 9.714105606
# Predicted y is [9.78207036], true y is 9.804385185
# Predicted y is [9.70139731], true y is 10.09328079
# Predicted y is [9.78243781], true y is 9.984944344
# Predicted y is [9.78137715], true y is 10.03008366
# Predicted y is [9.69098904], true y is 10.1384201
# Predicted y is [9.78088628], true y is 10.20161629
# Predicted y is [10.07102268], true y is 10.07522392
# Predicted y is [9.96171657], true y is 10.01202869
# Predicted y is [10.0060529], true y is 10.11133575
# Predicted y is [10.11540564], true y is 10.12036324
# Predicted y is [10.17864237], true y is 9.79535675
# Predicted y is [10.05345715], true y is 9.966888428
# Predicted y is [9.99095133], true y is 9.984944344
# Predicted y is [10.09031943], true y is 9.957859993
# Predicted y is [10.09696825], true y is 10.2196722
# Predicted y is [9.7753417], true y is 10.03911209
# Predicted y is [9.94485812], true y is 9.732160568
# Predicted y is [9.96285513], true y is 9.813412666
# Predicted y is [9.93529134], true y is 9.723133087
# Predicted y is [10.20086235], true y is 9.605769157
# Predicted y is [10.01709363], true y is 9.659936905
# Predicted y is [9.71355153], true y is 9.488406181
# Predicted y is [9.79266032], true y is 9.416181564
# Predicted y is [9.70110635], true y is 9.21756649
# Predicted y is [9.58431303], true y is 8.973810196
# Predicted y is [9.64135385], true y is 9.109230995
# Predicted y is [9.46926815], true y is 8.88353157
# Predicted y is [9.39663832], true y is 9.082146645
# Predicted y is [9.19767782], true y is 9.163397789
# Predicted y is [8.9576608], true y is 9.235621452
# Predicted y is [9.0909321], true y is 9.244648933
# Predicted y is [8.86432625], true y is 9.280761719
# Predicted y is [9.06226145], true y is 9.163397789
# Predicted y is [9.1435937], true y is 9.109230995
# Predicted y is [9.21538305], true y is 9.208538055
# Predicted y is [9.22390211], true y is 9.163397789
# Predicted y is [9.25974351], true y is 9.280761719
# Predicted y is [9.14284531], true y is 9.244648933
# Predicted y is [9.08843265], true y is 9.208538055
# Predicted y is [9.18668093], true y is 9.21756649
# Predicted y is [9.14144194], true y is 9.127285957
# Predicted y is [9.25946781], true y is 9.253678322
# Predicted y is [9.22276529], true y is 9.19048214
# Predicted y is [9.18624976], true y is 9.172426224
# Predicted y is [9.19562275], true y is 9.208538055
# Predicted y is [9.10511261], true y is 9.127285957
# Predicted y is [9.23174001], true y is 9.055062294
# Predicted y is [9.16843446], true y is 9.091174126
# Predicted y is [9.15038096], true y is 9.082146645
# Predicted y is [9.18738895], true y is 9.082146645
# Predicted y is [9.10654506], true y is 9.334929466
# Predicted y is [9.03386214], true y is 9.325901985
# Predicted y is [9.06961653], true y is 9.578684807
# Predicted y is [9.06075755], true y is 9.596741676
# Predicted y is [9.06076928], true y is 9.443265915
# Predicted y is [9.31671878], true y is 9.380069733
# Predicted y is [9.30510379], true y is 9.425209045
# Predicted y is [9.55763436], true y is 9.416181564
# Predicted y is [9.57510619], true y is 9.334929466
# Predicted y is [9.42352358], true y is 9.371041298
# Predicted y is [9.3586884], true y is 9.298818588
# Predicted y is [9.40299723], true y is 9.280761719
# Predicted y is [9.39407227], true y is 9.31687355
# Predicted y is [9.31287751], true y is 9.343958855
# Predicted y is [9.34837407], true y is 9.398125648
# Predicted y is [9.27646989], true y is 9.325901985
# Predicted y is [9.25821725], true y is 9.154370308
# Predicted y is [9.29442822], true y is 9.271734238
# Predicted y is [9.3210241], true y is 9.271734238
# Predicted y is [9.37590903], true y is 9.343958855
# Predicted y is [9.30325859], true y is 9.506461143
# Predicted y is [9.13355198], true y is 9.542572975
# Predicted y is [9.24946903], true y is 9.614796638
# Predicted y is [9.24930144], true y is 9.641880989
# Predicted y is [9.32196387], true y is 9.659936905
# Predicted y is [9.48608785], true y is 9.605769157
# Predicted y is [9.52072741], true y is 9.632853508
# Predicted y is [9.59280655], true y is 9.578684807
# Predicted y is [9.61945221], true y is 9.641880989
# Predicted y is [9.63761588], true y is 9.55160141
# Predicted y is [9.58244145], true y is 9.461320877
# Predicted y is [9.60984323], true y is 9.524517059
# Predicted y is [9.55554768], true y is 9.343958855
# Predicted y is [9.61837702], true y is 9.43423748
# Predicted y is [9.52837552], true y is 9.45229435
# Predicted y is [9.43949646], true y is 9.479377747
# Predicted y is [9.50249107], true y is 9.578684807
# Predicted y is [9.32262842], true y is 9.524517059
# Predicted y is [9.41158787], true y is 9.461320877
# Predicted y is [9.42938449], true y is 9.569657326
# Predicted y is [9.45694781], true y is 9.542572975
# Predicted y is [9.55822509], true y is 9.55160141
# Predicted y is [9.502379], true y is 9.696048737
# Predicted y is [9.43880496], true y is 9.975915909
# Predicted y is [9.54712906], true y is 10.10230732
# Predicted y is [9.52077039], true y is 11.01413441
# Predicted y is [9.52914451], true y is 10.93288231
# Predicted y is [9.6747477], true y is 10.95996571
# Predicted y is [9.95654587], true y is 10.82454681
# Predicted y is [10.08509207], true y is 10.47245598
# Predicted y is [11.00175489], true y is 10.52662277
# Predicted y is [10.9185708], true y is 10.27383995
# Predicted y is [10.94224796], true y is 10.09328079
# Predicted y is [10.80566766], true y is 10.11133575
# Predicted y is [10.45336031], true y is 10.17453194
# Predicted y is [10.50954688], true y is 10.40023136
# Predicted y is [10.2556771], true y is 10.41828728
# Predicted y is [10.07736688], true y is 10.49051094
# Predicted y is [10.09587057], true y is 10.31915951
# Predicted y is [10.15534913], true y is 9.919340134
# Predicted y is [10.38143394], true y is 9.871742249
# Predicted y is [10.39646971], true y is 9.890781403
# Predicted y is [10.47383821], true y is 10.00501537
# Predicted y is [10.30167366], true y is 9.900300026
# Predicted y is [9.90167061], true y is 9.862221718
# Predicted y is [9.85075139], true y is 9.909819603
# Predicted y is [9.86821998], true y is 10.14780807
# Predicted y is [9.98358418], true y is 10.00501537
# Predicted y is [9.8786758], true y is 10.02405453
# Predicted y is [9.84383941], true y is 9.928859711
# Predicted y is [9.89012394], true y is 10.01453495
# Predicted y is [10.13119727], true y is 9.966937065
# Predicted y is [9.98367788], true y is 10.05261326
# Predicted y is [10.00220555], true y is 10.00501537
# Predicted y is [9.9076005], true y is 10.08117199
# Predicted y is [9.99352854], true y is 10.31915951
# Predicted y is [9.94793969], true y is 10.17636585
# Predicted y is [10.03075133], true y is 10.07165146
# Predicted y is [9.98116817], true y is 9.966937065
# Predicted y is [10.05849396], true y is 9.995495796
# Predicted y is [10.30315566], true y is 9.957417488
# Predicted y is [10.15536966], true y is 9.947897911
# Predicted y is [10.04973826], true y is 9.871742249
# Predicted y is [9.94668138], true y is 9.852703094
# Predicted y is [9.97238728], true y is 9.957417488
# Predicted y is [9.93539122], true y is 9.862221718
# Predicted y is [9.92577363], true y is 9.795585632
# Predicted y is [9.85008374], true y is 9.690871239
# Predicted y is [9.83002348], true y is 9.633753777
# Predicted y is [9.93714795], true y is 9.586155891
# Predicted y is [9.84566077], true y is 9.529039383
# Predicted y is [9.77604069], true y is 9.567117691
# Predicted y is [9.67208547], true y is 9.529039383
# Predicted y is [9.61320763], true y is 9.481441498
# Predicted y is [9.56549714], true y is 9.443364143
# Predicted y is [9.51109958], true y is 9.424324036
# Predicted y is [9.54833643], true y is 9.386245728
# Predicted y is [9.50996396], true y is 9.386245728
# Predicted y is [9.46313993], true y is 9.35768795
# Predicted y is [9.42468543], true y is 9.462402344
# Predicted y is [9.40434111], true y is 9.367207527
# Predicted y is [9.36737224], true y is 9.233934402
# Predicted y is [9.36797681], true y is 9.167297363
# Predicted y is [9.33849893], true y is 9.043543816
# Predicted y is [9.44927262], true y is 9.014985085
# Predicted y is [9.34957439], true y is 9.005465508
# Predicted y is [9.21805204], true y is 8.97690773
# Predicted y is [9.14868724], true y is 8.938829422
# Predicted y is [9.02689549], true y is 8.967388153
# Predicted y is [8.99542105], true y is 9.129220009
# Predicted y is [8.98553725], true y is 9.081622124
# Predicted y is [8.95792549], true y is 9.072102547
# Predicted y is [8.92074159], true y is 9.157777786
# Predicted y is [8.94928508], true y is 9.252973557
# Predicted y is [9.11383157], true y is 9.186336517
# Predicted y is [9.06162327], true y is 9.119699478
# Predicted y is [9.05399179], true y is 9.233934402
# Predicted y is [9.14221384], true y is 9.186336517
# Predicted y is [9.23812247], true y is 9.233934402
# Predicted y is [9.17294508], true y is 9.138739586
# Predicted y is [9.10186644], true y is 9.024504662
# Predicted y is [9.21751441], true y is 8.948348045
# Predicted y is [9.16832075], true y is 8.919790268
# Predicted y is [9.21867316], true y is 8.815075874
# Predicted y is [9.12158101], true y is 8.805555344
# Predicted y is [9.0059686], true y is 8.853153229
# Predicted y is [8.93107702], true y is 8.891231537
# Predicted y is [8.90235964], true y is 8.910269737
# Predicted y is [8.79958369], true y is 8.938829422
# Predicted y is [8.78891807], true y is 8.97690773
# Predicted y is [8.83898097], true y is 9.005465508
# Predicted y is [8.87472437], true y is 9.100661278
# Predicted y is [8.89438646], true y is 8.97690773
# Predicted y is [8.92383488], true y is 8.910269737
# Predicted y is [8.96487243], true y is 8.99594593
# Predicted y is [8.99273384], true y is 9.072102547
# Predicted y is [9.08507279], true y is 9.233934402
# Predicted y is [8.96027255], true y is 9.272011757
# Predicted y is [8.89302523], true y is 9.205375671
# Predicted y is [8.97675228], true y is 9.424324036
# Predicted y is [9.05452877], true y is 9.376727104
# Predicted y is [9.22344891], true y is 9.33864975
# Predicted y is [9.25572004], true y is 9.500480652
# Predicted y is [9.1872047], true y is 9.709910393
# Predicted y is [9.41101707], true y is 9.576637268
# Predicted y is [9.3597057], true y is 9.805105209
# Predicted y is [9.32177477], true y is 9.757507324
# Predicted y is [9.48426917], true y is 9.747987747
# Predicted y is [9.6980789], true y is 9.681351662
# Predicted y is [9.57650929], true y is 9.510000229
# Predicted y is [9.79221359], true y is 9.500480652
# Predicted y is [9.74118525], true y is 9.433843613
# Predicted y is [9.72903204], true y is 9.348168373
# Predicted y is [9.66142924], true y is 9.233934402
# Predicted y is [9.49204036], true y is 9.281532288
# Predicted y is [9.4792935], true y is 9.243453979
# Predicted y is [9.41447438], true y is 9.186336517
# Predicted y is [9.32854793], true y is 9.300571442
# Predicted y is [9.21587103], true y is 9.291051865
# Predicted y is [9.26208772], true y is 9.281532288
# Predicted y is [9.22422846], true y is 9.148258209
# Predicted y is [9.16840891], true y is 9.091141701
# Predicted y is [9.28156956], true y is 9.091141701
# Predicted y is [9.27071883], true y is 9.119699478
# Predicted y is [9.26124609], true y is 9.110179901
# Predicted y is [9.13077809], true y is 9.072102547
# Predicted y is [9.07242187], true y is 9.043543816
# Predicted y is [9.07071033], true y is 9.214895248
# Predicted y is [9.09885346], true y is 9.224413872
# Predicted y is [9.0907793], true y is 9.214895248
# Predicted y is [9.05413848], true y is 9.348168373
# Predicted y is [9.02702299], true y is 9.33864975
# Predicted y is [9.19909145], true y is 9.35768795
# Predicted y is [9.2081902], true y is 9.224413872
# Predicted y is [9.19758494], true y is 9.310090065
# Predicted y is [9.33133921], true y is 9.367207527
# Predicted y is [9.3212625], true y is 9.395766258
# Predicted y is [9.3400671], true y is 9.443364143
# Predicted y is [9.20981391], true y is 9.595675468
# Predicted y is [9.29276877], true y is 9.671832085
# Predicted y is [9.34971674], true y is 9.500480652
# Predicted y is [9.37794081], true y is 9.490961075
# Predicted y is [9.43624765], true y is 9.319609642
# Predicted y is [9.58217472], true y is 9.252973557
# Predicted y is [9.65635177], true y is 9.214895248
# Predicted y is [9.48365001], true y is 9.26249218
# Predicted y is [9.47255481], true y is 9.195856094
# Predicted y is [9.30289063], true y is 9.481441498
# Predicted y is [9.23524873], true y is 9.938378334
# Predicted y is [9.19584892], true y is 9.728949547
# Predicted y is [9.24516128], true y is 9.767027855
# Predicted y is [9.17843331], true y is 9.786066055
# Predicted y is [9.47072485], true y is 10.20492554
# Predicted y is [9.93416888], true y is 10.20492554
# Predicted y is [9.71928144], true y is 10.16684723
# Predicted y is [9.75718118], true y is 10.17636585
# Predicted y is [9.77128673], true y is 10.30963993
# Predicted y is [10.20137766], true y is 10.44291306
# Predicted y is [10.19412437], true y is 10.19540596
# Predicted y is [10.15157208], true y is 10.26204205
# Predicted y is [10.1617021], true y is 10.09069157
# Predicted y is [10.29921746], true y is 10.2810812
# Predicted y is [10.42943382], true y is 10.0335741
# Predicted y is [10.18343592], true y is 10.07165146
# Predicted y is [10.24558654], true y is 9.966937065
# Predicted y is [10.0754514], true y is 10.39531612
# Predicted y is [10.264121], true y is 10.35723782
# Predicted y is [10.01701523], true y is 10.33819771
# Predicted y is [10.05114107], true y is 10.23348427
# Predicted y is [9.94931667], true y is 10.21444416
# Predicted y is [10.38085916], true y is 10.20492554
# Predicted y is [10.33819011], true y is 10.37627602
# Predicted y is [10.31881903], true y is 10.37627602
# Predicted y is [10.21550327], true y is 10.58570576
# Predicted y is [10.19696273], true y is 10.57618618
# Predicted y is [10.18337452], true y is 10.39531612
# Predicted y is [10.35732909], true y is 10.50003052
# Predicted y is [10.35762941], true y is 10.1382885
# Predicted y is [10.57050744], true y is 10.23348427
# Predicted y is [10.55506198], true y is 10.26204205
# Predicted y is [10.37393711], true y is 10.16684723
# Predicted y is [10.47739288], true y is 10.11924934
# Predicted y is [10.12355677], true y is 10.10972977
# Predicted y is [10.2137498], true y is 9.976456642
# Predicted y is [10.23985013], true y is 10.48099136
# Predicted y is [10.14465122], true y is 10.46195221
# Predicted y is [10.0971646], true y is 10.36675739
# Predicted y is [10.08735092], true y is 10.24300385
# Predicted y is [9.96098521], true y is 10.18588638
# Predicted y is [10.47363791], true y is 10.1382885
# Predicted y is [10.44143221], true y is 10.14780807
# Predicted y is [10.34424202], true y is 10.08117199
# Predicted y is [10.22314992], true y is 10.21444416
# Predicted y is [10.16234767], true y is 10.24300385
# Predicted y is [10.11829574], true y is 10.08117199
# Predicted y is [10.12542677], true y is 9.928859711
# Predicted y is [10.05863035], true y is 10.0335741
# Predicted y is [10.19366487], true y is 10.07165146
# Predicted y is [10.22158435], true y is 9.995495796
# Predicted y is [10.05949997], true y is 10.07165146
# Predicted y is [9.90870562], true y is 9.928859711
# Predicted y is [10.01049777], true y is 9.928859711
# Predicted y is [10.05057709], true y is 9.805105209
# Predicted y is [9.97213883], true y is 9.776547432
# Predicted y is [10.04998555], true y is 9.757507324
# Predicted y is [9.90729275], true y is 10.0335741
# Predicted y is [9.90518591], true y is 9.567117691
# Predicted y is [9.78458678], true y is 9.614715576
# Predicted y is [9.75348909], true y is 9.548078537
# Predicted y is [9.73579879], true y is 9.471921921
# Predicted y is [10.01239737], true y is 9.567117691
# Predicted y is [9.56114165], true y is 9.633753777
# Predicted y is [9.59676442], true y is 9.605195999
# Predicted y is [9.53177625], true y is 9.700389862
# Predicted y is [9.45456931], true y is 9.71942997
# Predicted y is [9.54701547], true y is 9.728949547
# Predicted y is [9.6145958], true y is 9.633753777
# Predicted y is [9.58555243], true y is 9.671832085
# Predicted y is [9.68043671], true y is 9.605195999
# Predicted y is [9.69923959], true y is 9.605195999
# Predicted y is [9.70533644], true y is 9.824144363
# Predicted y is [9.61177252], true y is 9.852703094
# Predicted y is [9.65046377], true y is 9.795585632
# Predicted y is [9.58324376], true y is 9.852703094
# Predicted y is [9.58261051], true y is 9.776547432
# Predicted y is [9.80715692], true y is 9.700389862
# Predicted y is [9.83306828], true y is 9.728949547
# Predicted y is [9.77580876], true y is 9.73846817
# Predicted y is [9.83053638], true y is 9.73846817
# Predicted y is [9.75500553], true y is 9.73846817
# Predicted y is [9.67971643], true y is 9.81462574
# Predicted y is [9.70741458], true y is 9.71942997
# Predicted y is [9.71893452], true y is 9.73846817
# Predicted y is [9.72126975], true y is 9.681351662
# Predicted y is [9.7169549], true y is 9.548078537
# Predicted y is [9.79462317], true y is 9.567117691
# Predicted y is [9.70044794], true y is 9.557598114
# Predicted y is [9.71812007], true y is 9.614715576
# Predicted y is [9.66275703], true y is 9.557598114
# Predicted y is [9.52862377], true y is 9.519519806
# Predicted y is [9.54575362], true y is 9.510000229
# Predicted y is [9.53596274], true y is 9.53855896
# Predicted y is [9.59469236], true y is 9.595675468
# Predicted y is [9.53722002], true y is 9.529039383
# Predicted y is [9.49995545], true y is 9.500480652
# Predicted y is [9.48913361], true y is 9.519519806
# Predicted y is [9.51724086], true y is 9.548078537
# Predicted y is [9.5762081], true y is 9.45288372
# Predicted y is [9.50787533], true y is 9.443364143
# Predicted y is [9.47944386], true y is 9.510000229
# Predicted y is [9.49702461], true y is 9.548078537
# Predicted y is [9.5273875], true y is 9.462402344
# Predicted y is [9.43436534], true y is 9.433843613
# Predicted y is [9.42404713], true y is 9.433843613
# Predicted y is [9.48954798], true y is 9.481441498
# Predicted y is [9.5272221], true y is 9.35768795
# Predicted y is [9.44126581], true y is 9.462402344
# Predicted y is [9.41329482], true y is 9.500480652
# Predicted y is [9.41314899], true y is 9.529039383
# Predicted y is [9.46071148], true y is 9.510000229

# %% [markdown]
# As we can see from the details above, the model is doing a great job at predicting stock price that it hasn't seen before with a good accuracy. Perhaps you can just utilize this model to predict the stock price after 5 days, but there are heaps of limitations: <br>1. Since even a change of one penny in the price matters in stock investment, the model's accuracy is not up to our standard yet.
# <br>2. What we really need is for the model to tell us how price is going to change compared with today, so we can take actions (buy/sell/hold). Instead of using volume and price to make predictions, we could probably use percent change to predict percent change.

# %% [markdown]
# ## *A classification model
# In this section we want to combine the algo trading we have done earlier with machine learning.
# <br>Basically, we want to test whether those indicators are helpful with predicting whether the stock price will go up in 5 days.

# %%
def mtm_func(stock_price,time_frame=10):
    '''
    mtm(momentum)
    
    (current stock price/stock price n days ago) - 1
    
    '''
    mtm = stock_price / (stock_price.shift(time_frame)) - 1
    
    return mtm

def boll_func(stock_price,time_frame=10):
    '''
    boll(bollinger bands)
    
    mid line is n-day SMA
    upper line is SMA+2*std(std of the stock price in the past n days)
    lower line is SMA-2*std
    
    once the stock price goes beyond the upper line (or lower line), it signifies a sell (or buy) opportunity
    
    '''
    sma = stock_price.rolling(time_frame).mean()
    sigma = stock_price.rolling(time_frame).std()
    upper = sma + 2*sigma
    lower = sma - 2*sigma
    bolli = (stock_price - sma) / (2*sigma)
    
    return bolli, sma, upper, lower

def macd_func(stock_price,slow=26,fast=12):
    '''
    macd(moving average convergence divergence)
    
    diff = emafast - emaslow
    dea = ema(diff,9)
    histogram = diff - dea
    
    when histogram>0, diff is greater than dea (past 9-day diff average), fast and slow lines are diverging, signifying an upward trend in stock price
    or vice versa
    
    '''
    emaSlow = stock_price.ewm(span=slow,adjust=True).mean()
    emaFast = stock_price.ewm(span=fast,adjust=True).mean()
    diff = emaFast-emaSlow
    dea = diff.ewm(span=9,adjust=True).mean()
    macdi = diff - dea
    
    return macdi, emaSlow, emaFast, diff, dea

# %%
data_path = 'stock_data/'
stock_code = '600000_浦发银行.csv'
df = pd.read_csv(data_path + stock_code)
df['Adj Close T+3'] = df['Adj Close'].shift(-3)
df.head(10)
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close  \
# 0   4/01/2000  3.005759  2.885668  2.912484  2.981274   38562183   1.814433
# 1   5/01/2000  3.029077  2.932305  2.981274  2.947462   45052693   1.793855
# 2   6/01/2000  3.066387  2.920646  2.935803  3.030243   53430896   1.844237
# 3   7/01/2000  3.206298  3.045400  3.066387  3.136342  183161852   1.908809
# 4  10/01/2000  3.247105  3.114190  3.148002  3.177150  141859094   1.933645
# 5  11/01/2000  3.182979  3.045400  3.177150  3.054728   80543448   1.859138
# 6  12/01/2000  3.031409  2.891498  3.031409  2.928807  302548283   1.782502
# 7  13/01/2000  2.943964  2.891498  2.914816  2.903157   68406039   1.766890
# 8  14/01/2000  2.914816  2.787730  2.900825  2.821542  153198958   1.717219
# 9  17/01/2000  2.849524  2.769075  2.807551  2.844861   69485695   1.731411
#
#    Adj Close T+3
# 0       1.908809
# 1       1.933645
# 2       1.859138
# 3       1.782502
# 4       1.766890
# 5       1.717219
# 6       1.731411
# 7       1.712962
# 8       1.712252
# 9       1.734249

# %%
# construct new columns of data
df['price_change'] = (df['Adj Close T+3'] - df['Adj Close'])/ df['Adj Close']
df['mtm'] = mtm_func(df['Adj Close'])
df['bolli'],*k = boll_func(df['Adj Close']) 
df['macdi'],*k = macd_func(df['Adj Close'])
df['smai'] = df['Adj Close'].rolling(5).mean() - df['Adj Close'].rolling(10).mean()
df['up'] = [1 if df.loc[i,'price_change'] > 0 else 0 for i in df.index]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

# handle missing data by dropping nan rows
df.dropna(inplace=True)

# split data into features and labels
X = df[['bolli','macdi','mtm']]
y = df['up']

# perform feature scaling, so that Volume and Adj Close are on the same scale
X = scale(X)

# split data into training and testing sets
# turn shuffle to False as what we have is a time series data, and we want to keep them in order
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=False)

# %%
# choose a model
from sklearn import svm
clf_svm = svm.SVC()

# train the model
clf_svm.fit(X_train,y_train)

# test the model
clf_svm.score(X_test,y_test)
# Out:
# 0.5590243902439025
