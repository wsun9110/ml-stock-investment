# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import time
import matplotlib.pyplot as plt

# %%
def macd_func(stock_price,slow=26,fast=12):
    '''
    macd(moving average convergence divergence)
    
    dif = emafast - emaslow
    dea = ema(dif,9)
    histogram = dif - dea
    
    when histogram>0, current diff between fast line and slow line is greater than dea (past 9-day diff average), fast and slow lines are diverging, signifying an upward trend in stock price
    or vice versa
    
    '''
    emaSlow=stock_price.ewm(span=slow,adjust=True).mean()
    emaFast=stock_price.ewm(span=fast,adjust=True).mean()
    macd=emaFast-emaSlow
    signal=macd.ewm(span=9,adjust=True).mean()
    
    return emaSlow,emaFast,macd,signal
            

def mtm_func(stock_price,time_frame=10):
    '''
    mtm(momentum)
    
    (current stock price/stock price n days ago -1)*100%
    
    '''
    mtm=stock_price/(stock_price.shift(time_frame))-1
    
    return mtm


def boll_func(stock_price,time_frame=10):
    '''
    boll(bollinger bands)
    
    mid line is n-day SMA
    upper line is SMA+2*std(stock prices in the past n days)
    lower line is SMA-2*std(stock prices in the past n days)
    
    once the stock price goes beyond the upper line (or lower line) and starts to go down (up), it is a sell (or buy) signal
    
    '''
    sma=stock_price.rolling(time_frame).mean()
    sigma=stock_price.rolling(time_frame).std()
    upper=sma+2*sigma
    lower=sma-2*sigma
    bolli=(stock_price-sma)/(2*sigma)
    
    return bolli,sma,upper,lower

# %%
data_path='stock_data/'
ticker_list=[i for i in os.walk(data_path)][0][2]
ret_list=[]
for each_ticker in ticker_list:

    df=pd.read_csv(data_path+each_ticker)
    df['Adj Close T-1']=df['Adj Close'].shift(1)
    df['bolli']=boll_func(df['Adj Close'])[0]
    df['mtm']=mtm_func(df['Adj Close'],5)
    df['action']=0
    df['cost']=0
    df['hold']=0
    df['profit']=0

    for i in range(1,len(df)):

    # when we are not holding the stock, plus both boll and mtm meet our conditions,then we buy,update our holding status and holding cost
        if df.loc[i-1,'bolli']<=-1 and df.loc[i-1,'mtm']>=0 and df.loc[i-1,'hold']==0:
            df.loc[i,'hold']=1
            df.loc[i,'action']=1
            df.loc[i,'cost']=df.loc[i,'Adj Close T-1']
            df.loc[i,'profit']=df.loc[i,'Adj Close']-df.loc[i,'Adj Close T-1']
    #         print(df.loc[i+1])
            continue

    # we are holding the stock,but the current price has dropped over 8%,then we sell to stop loss,update our holding status and holding cost
        if df.loc[i-1,'hold']==1 and ((df.loc[i-1,'Adj Close']-df.loc[i-1,'cost'])/df.loc[i-1,'cost']<=-0.08 
                                    or (df.loc[i-1,'Adj Close']-df.loc[i-1,'cost'])/df.loc[i-1,'cost']>=0.08):
            df.loc[i,'hold']=0
            df.loc[i,'action']=-1
            df.loc[i,'cost']=0
    #         print(df.loc[i+1])
            continue

    # if neither of the above occurs,just fill down the status and cost   
        if df.loc[i-1,'hold']==1:
            df.loc[i,'hold']=1
            df.loc[i,'cost']=df.loc[i-1,'cost']
            df.loc[i,'profit']= df.loc[i,'Adj Close']- df.loc[i,'Adj Close T-1']
        else:
            df.loc[i,'hold']=0
            df.loc[i,'cost']=0


    df['daily_ret']=[df.loc[ind,'profit']/df.loc[ind,'cost'] if df.loc[ind,'hold']==1 else 0
                 for ind in df.index]


    daily_ret_avg=df[df['hold']!=0]['daily_ret'].mean()

    ret_list.append(daily_ret_avg)

# %%
for a,b in zip(ticker_list,ret_list):
    print(a,b)
# Out:
# 600000_浦发银行.csv nan
# 600004_白云机场.csv nan
# 600006_东风汽车.csv 0.0033163067206722113
# 600007_中国国贸.csv nan
# 600008_首创股份.csv nan
# 600009_上海机场.csv nan
# 600010_包钢股份.csv nan
# 600011_华能国际.csv -0.003073091546497565
# 600012_皖通高速.csv 0.0027777759870063474
# 600015_华夏银行.csv nan
# 600016_民生银行.csv nan
# 600017_日照港.csv nan
# 600018_上港集团.csv nan
# 600019_宝钢股份.csv nan
# 600020_中原高速.csv nan
# 600021_上海电力.csv nan
# 600022_济南钢铁.csv nan
# 600026_中海发展.csv nan
# 600027_华电国际.csv nan
# 600028_中国石化.csv nan
# 600029_南方航空.csv nan
# 600030_中信证券.csv nan
# 600031_三一重工.csv nan
# 600033_福建高速.csv nan
# 600035_楚天高速.csv nan
# 600036_招商银行.csv nan
# 600037_歌华有线.csv nan
# 600038_哈飞股份.csv nan
# 600039_四川路桥.csv nan
# 600048_保利地产.csv nan
# 600050_中国联通.csv nan
# 600051_宁波联合.csv nan
# 600052_浙江广厦.csv nan
# 600053_中江地产.csv nan
# 600054_黄山旅游.csv nan
# 600055_万东医疗.csv nan
# 600056_中国医药.csv 0.005333667163790745
# 600058_五矿发展.csv nan
# 600059_古越龙山.csv nan
# 600060_海信电器.csv nan
# 600061_中纺投资.csv nan
# 600062_双鹤药业.csv nan
# 600063_皖维高新.csv nan
# 600064_南京高科.csv nan
# 600066_宇通客车.csv nan
# 600067_冠城大通.csv -0.0028226851025830255
# 600068_葛洲坝.csv nan
# 600070_浙江富润.csv -0.00151515045399732
# 600071_凤凰光学.csv nan
# 600072_中船股份.csv nan
# 600073_上海梅林.csv nan
# 600075_新疆天业.csv nan
# 600077_百科集团.csv nan
# 600078_澄星股份.csv nan
# 600079_人福科技.csv nan
# 600080_ST金花.csv nan
# 600081_东风科技.csv nan
# 600082_海泰发展.csv nan
# 600083_ST博信.csv nan
# 600084_ST中葡.csv 0.0007723328456442982
# 600085_同仁堂.csv nan
# 600088_中视传媒.csv nan
# 600089_特变电工.csv nan
# 600090_啤酒花.csv nan
# 600091_明天科技.csv nan
# 600093_禾嘉股份.csv nan
# 600095_哈高科.csv nan
# 600096_云天化.csv nan
# 600097_开创国际.csv nan
# 600098_广州控股.csv 0.05000013250535149
# 600099_林海股份.csv nan
# 600100_同方股份.csv -0.0017072335162202873
# 600101_明星电力.csv nan
# 600103_青山纸业.csv nan
# 600104_上海汽车.csv nan
# 600105_永鼎股份.csv nan
# 600106_重庆路桥.csv 0.0015581723067016728
# 600107_美尔雅.csv nan
# 600108_亚盛集团.csv nan
# 600109_国金证券.csv nan
# 600110_中科英华.csv nan
# 600111_包钢稀土.csv nan
# 600112_长征电气.csv nan
# 600790_轻纺城.csv nan
# 600791_京能置业.csv 0.0014170648334036226
# 600792_ST马龙.csv nan
# 600793_ST宜纸.csv nan
# 600794_保税科技.csv nan
# 600795_国电电力.csv nan
# 600796_钱江生化.csv nan
# 600797_浙大网新.csv 0.04425472749156093
# 600798_宁波海运.csv nan
# 600800_ST磁卡.csv nan
# 600801_华新水泥.csv nan
# 600802_福建水泥.csv nan
# 600803_威远生化.csv nan
# 600804_鹏博士.csv nan
# 600805_悦达投资.csv 0.002935952553469799
# 600806_昆明机床.csv nan
# 600807_天业股份.csv nan
# 600808_马钢股份.csv nan
# 600809_山西汾酒.csv nan
# 600810_神马实业.csv nan
# 600811_东方集团.csv 0.0008733626744310169
# 600812_华北制药.csv nan
# 600814_杭州解百.csv nan
# 600815_厦工股份.csv nan
# 600816_安信信托.csv nan
# 600818_中路股份.csv -0.0019705719832074048
# 600819_耀皮玻璃.csv nan
# 600820_隧道股份.csv nan
# 600821_津劝业.csv nan
# 600822_上海物贸.csv nan
# 600823_世茂股份.csv nan
# 600824_益民商业.csv nan
# 600825_新华传媒.csv -0.0009484645306771733
# 600826_兰生股份.csv nan
# 600827_友谊股份.csv nan
# 600828_成商集团.csv nan
# 600829_三精制药.csv nan
# 600830_香溢融通.csv nan
# 600831_广电网络.csv nan
# 600833_第一医药.csv nan
# 600834_申通地铁.csv nan
# 600835_上海机电.csv nan
# 600836_界龙实业.csv nan
# 600837_海通证券.csv nan
# 600838_上海九百.csv nan
# 600839_四川长虹.csv -0.013070052878198544
# 600841_上柴股份.csv nan
# 600843_上工申贝.csv nan
# 600844_丹化科技.csv nan
# 600845_宝信软件.csv nan
# 600846_同济科技.csv nan
# 600847_ST渝万里.csv -0.0006967240962858271
# 600848_自仪股份.csv nan
# 600850_华东电脑.csv nan
# 600851_海欣股份.csv 0.0013198511102851223
# 600853_龙建股份.csv nan
# 600854_ST春兰.csv nan
# 600855_航天长峰.csv nan
# 600856_长百集团.csv nan
# 600857_工大首创.csv nan
# 600858_银座股份.csv nan
# 600859_王府井.csv nan
# 600860_北人股份.csv nan
# 600861_北京城乡.csv nan
# 600862_南通科技.csv nan
# 600863_内蒙华电.csv nan
# 600864_哈投股份.csv nan
# 600865_百大集团.csv nan
# 600866_星湖科技.csv nan
# 600867_通化东宝.csv -0.0013145726420255594
# 600868_ST梅雁.csv nan
# 600869_三普药业.csv nan
# 600871_S仪化.csv nan
# 600872_中炬高新.csv nan
# 600873_五洲明珠.csv nan
# 600874_创业环保.csv nan
# 600875_东方电气.csv nan
# 600876_ST洛玻.csv nan
# 600877_中国嘉陵.csv -0.0008117965813491948
# 600879_航天电子.csv nan
# 600880_博瑞传播.csv 0.0093609051592708
# 600881_亚泰集团.csv 0.10075175630922596
# 600882_大成股份.csv nan
# 600883_博闻科技.csv nan
# 600884_杉杉股份.csv nan
# 600885_力诺太阳.csv -0.0015141287366734406
# 600886_国投电力.csv nan
# 600888_新疆众和.csv nan
# 600889_南京化纤.csv nan
# 600892_ST湖科.csv nan
# 600893_航空动力.csv nan
# 600894_广钢股份.csv nan
# 600895_张江高科.csv nan
# 600896_中海海盛.csv nan
# 600897_厦门空港.csv nan
# 600900_长江电力.csv nan
# 600960_滨州活塞.csv nan
# 600961_株冶集团.csv nan
# 600962_国投中鲁.csv nan
# 600963_岳阳纸业.csv nan
# 600965_福成五丰.csv nan
# 600966_博汇纸业.csv nan
# 600967_北方创业.csv nan
# 600969_郴电国际.csv nan
# 600970_中材国际.csv nan
# 600971_恒源煤电.csv nan
# 600973_宝胜股份.csv nan
# 600975_新五丰.csv nan
# 600976_武汉健民.csv 0.0007729508701168089
# 600978_宜华木业.csv nan
# 600979_广安爱众.csv nan
# 600980_北矿磁材.csv -0.076220439650355
# 600981_江苏开元.csv nan
# 600982_宁波热电.csv nan
# 600983_合肥三洋.csv nan
# 600984_ST建机.csv nan
# 600985_雷鸣科化.csv nan
# 600986_科达股份.csv nan
# 600987_航民股份.csv nan
# 600988_ST宝龙.csv nan
# 600990_四创电子.csv nan
# 600992_贵绳股份.csv nan
# 600993_马应龙.csv nan
# 600995_文山电力.csv nan
# 600997_开滦股份.csv nan
# 600999_招商证券.csv 0.0016782540834698733
# 601001_大同煤业.csv nan
# 601002_晋亿实业.csv nan
# 601003_柳钢股份.csv nan
# 601005_重庆钢铁.csv nan
# 601006_大秦铁路.csv nan
# 601007_金陵饭店.csv nan
# 601008_连云港.csv nan
# 601009_南京银行.csv nan
# 601088_中国神华.csv nan
# 601099_太平洋.csv nan
# 601107_四川成渝.csv nan
# 601111_中国国航.csv nan
# 601117_中国化学.csv nan
# 601139_深圳燃气.csv nan
# 601166_兴业银行.csv nan
# 601168_西部矿业.csv nan
# 601169_北京银行.csv nan
# 601186_中国铁建.csv nan
# 601318_中国平安.csv nan
# 601328_交通银行.csv nan
# 601333_广深铁路.csv nan
# 601390_中国中铁.csv nan
# 601398_工商银行.csv nan
# 601588_北辰实业.csv nan
# 601600_中国铝业.csv nan
# 601601_中国太保.csv nan
# 601618_中国中冶.csv nan
# 601628_中国人寿.csv nan
# 601666_平煤股份.csv nan
# 601668_中国建筑.csv nan
# 601699_潞安环能.csv nan
# 601727_上海电气.csv nan
# 601766_中国南车.csv nan
# 601788_光大证券.csv nan
# 601808_中海油服.csv nan
# 601857_中国石油.csv nan
# 601866_中海集运.csv nan
# 601872_招商轮船.csv nan
# 601888_中国国旅.csv nan
# 601898_中煤能源.csv nan
# 601899_紫金矿业.csv nan
# 601918_国投新集.csv nan
# 601919_中国远洋.csv nan
# 601939_建设银行.csv nan
# 601958_金钼股份.csv nan
# 601988_中国银行.csv nan

# %%
ret_list_new=[x for x in ret_list if np.isnan(x)==False]
np.array(ret_list_new).mean()
# Out:
# 0.00480612855655113

# %% [markdown]
# compare with alipay fund:
# 1. annualized 7-day avg daily return of 2.0050%,which means on avg alipay fund daily return will be 2.0050%/365=0.0000548
# 2. our avg investment daily ret 0.004806 is much higher
#
# limitations:
# 1. the survivor bias
# 2. equal weights when computing our avg daily ret, should probably give more weights to closed dates
